# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Cardiotocographic.csv')

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %% [markdown]
# ##### Data cleaning and preparation

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
mode=df[['LB','AC','DS','DP','MLTV','Width','Tendency','NSP']].mode()
df1=df.fillna(mode)
df1
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df1[df1.duplicated()]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1115   39.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %%
df1=df1.drop_duplicates()
df1
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df2=[i for i in df1.columns if df1[i].dtypes!='0']
df2
# Out:
# ['LB',
#  'AC',
#  'FM',
#  'UC',
#  'DL',
#  'DS',
#  'DP',
#  'ASTV',
#  'MSTV',
#  'ALTV',
#  'MLTV',
#  'Width',
#  'Tendency',
#  'NSP']

# %%
df1.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2103.000000  2104.000000  2124.000000  2124.000000  2124.000000
# mean    133.342023     0.003220     0.009904     0.004394     0.001897
# std      11.268266     0.004392     0.067571     0.003340     0.003344
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001858     0.000000
# 50%     133.000000     0.001634     0.000000     0.004486     0.000000
# 75%     140.000000     0.005650     0.002568     0.006536     0.003292
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2103.000000  2103.000000  2124.000000  2124.000000  2124.000000
# mean      0.000003     0.000175    47.012459     1.364345    10.295650
# std       0.000142     0.000840    18.812403     1.174084    21.212676
# ...

# %% [markdown]
# #### Calculation of outliers

# %%
Q1=df1['FM'].quantile(0.25)
Q1
# Out:
# 0.0

# %%
Q3=df1['FM'].quantile(0.75)
Q3
# Out:
# 0.00256842175

# %%
IQR=Q3-Q1
IQR
# Out:
# 0.00256842175

# %%
lower_quantile=Q1-1.5*IQR
lower_quantile
# Out:
# -0.003852632625

# %%
upper_quantile=Q3+1.5*IQR
upper_quantile
# Out:
# 0.0064210543750000005

# %%
df1_no_outliers=df1[(df['FM']>lower_quantile)&(df1['FM']<upper_quantile)]
df1_no_outliers
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2120  140.000000  0.000000  0.000000  0.004975  0.001244  0.0  0.0  77.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
# Boxplot
plt.figure(figsize=(10,15))
df1_no_outliers.boxplot()
plt.show()

# %%
# Correlation
df1.corr()
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.064452  0.018810 -0.167012 -0.126981 -0.005439
# AC       -0.064452  1.000000  0.009407  0.071700 -0.093641 -0.033632
# FM        0.018810  0.009407  1.000000 -0.053386  0.009641  0.029899
# UC       -0.167012  0.071700 -0.053386  1.000000  0.189737 -0.006957
# DL       -0.126981 -0.093641  0.009641  0.189737  1.000000  0.058625
# DS       -0.005439 -0.033632  0.029899 -0.006957  0.058625  1.000000
# DP       -0.047726 -0.084644  0.121259  0.070504  0.145338  0.004282
# ASTV      0.242435 -0.231725 -0.032838 -0.182379 -0.069907  0.008441
# MSTV     -0.170134  0.134423  0.017061  0.189685  0.410216  0.016165
# ALTV      0.210955 -0.271554 -0.012005 -0.227881 -0.187275 -0.004406
# MLTV     -0.003225 -0.106308 -0.006157 -0.048862 -0.165494  0.034366
# Width    -0.118375  0.238422  0.097133  0.106787  0.409793  0.040831
# Tendency  0.237112  0.032399 -0.018410 -0.067098 -0.023838 -0.015408
# ...

# %% [markdown]
# ## Data visualization

# %%
sns.heatmap(df1.corr())
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.pairplot(data=df1)
plt.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# The exploratory data analysis (EDA) process has provided valuable insights into the distribution, relationships, and trends within the data. These findings not only guide the next steps in data preprocessing and model selection but also inform strategic decisions that could have significant business implications. Understanding the patterns and anomalies in the data enables more informed decision-making, leading to better outcomes in subsequent analyses and real-world applications.

# %%
# Standardize the data (0=mean, 1=std deviation)
from sklearn.preprocessing import StandardScaler
from numpy import set_printoptions

# %%
array = df1.values
scaler = StandardScaler()

# %%
scaler.fit(array)
# Out:
# StandardScaler()

# %%
rescaledX = scaler.transform(array)

# %%
# summarize transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[-1.18 -0.73 -0.15 -1.32 -0.57 -0.02 -0.21  1.38 -0.74  1.54 -0.76 -0.15
#    1.06  1.08]
#  [-0.12  0.72 -0.15  0.59  0.39 -0.02 -0.21 -1.6   0.63 -0.49  0.27  1.39
#   -0.49 -0.47]
#  [-0.03  0.02 -0.15  1.17  0.43 -0.02 -0.21 -1.65  0.63 -0.49  0.66  1.39
#   -0.49 -0.47]
#  [ 0.06 -0.15 -0.15  1.    0.2  -0.02 -0.21 -1.65  0.88 -0.49  1.89  1.08
#    1.06 -0.47]
#  [-0.12  0.75 -0.15  1.12 -0.57 -0.02 -0.21 -1.65  0.88 -0.49  1.49  1.08
#    1.06 -0.47]]

# %% [markdown]
# By observing analysis of above data we can say that DS,AC are highly correlated, DP and DS are highly correlated also AC and DP
# are highly correlated so we can drop any two of them.
